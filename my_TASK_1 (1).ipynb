# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/bartpiel/files-for-classes/refs/heads/main/Workshop-1/country_profile_variables.csv')

# %%
#Show 10 random df1 rows.
df.sample(10)
# Out:
#            country          Region Surface area (km2)  \
# 134       Mongolia     EasternAsia            1564116
# 185       Slovenia  SouthernEurope              20273
# 80       Gibraltar  SouthernEurope                  6
# 203           Togo   WesternAfrica              56785
# 124           Mali   WesternAfrica            1240192
# 78         Germany   WesternEurope             357376
# 135     Montenegro  SouthernEurope              13812
# 73   French Guiana    SouthAmerica              83534
# 81          Greece  SouthernEurope             131957
# 57         Denmark  NorthernEurope              42921
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 134                            3076                                 2.0
# 185                            2080                               103.3
# 80                               35                              3457.1
# 203                            7798                               143.4
# 124                           18542                                15.2
# 78                            82114                               235.6
# 135                             629                                46.8
# 73                              283                                 3.4
# 81                            11160                                86.6
# 57                             5734                               135.1
#
#      Sex ratio (m per 100 f, 2017)  \
# 134                           97.9
# 185                           98.6
# 80                           101.8
# 203                           99.4
# 124                          100.2
# 78                            97.0
# 135                           97.4
# 73                           100.0
# 81                            96.9
# 57                            99.0
#
#      GDP: Gross domestic product (million current US$)  \
# 134                                              11758
# 185                                              42777
# 80                                                 -99
# 203                                               4086
# 124                                              13100
# 78                                             3363600
# 135                                               4020
# 73                                                 -99
# 81                                              194860
# 57                                              301308
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 134                                            2.3
# 185                                            2.3
# 80                                             -99
# 203                                            5.5
# 124                                            7.6
# 78                                             1.7
# 135                                            4.5
# 73                                             -99
# 81                                            -0.2
# 57                                             1.6
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 134                        3973.4                            14.8  ...
# 185                       20689.8                             2.4  ...
# 80                          -99.0                             -99  ...
# 203                         559.4                            45.7  ...
# 124                         744.3                            39.9  ...
# 78                        41686.2                             0.6  ...
# 135                        6424.1                             9.8  ...
# 73                          -99.0                             -99  ...
# 81                        17788.0                             4.1  ...
# 57                        53149.3                             1.2  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 134                                               21.4
# 185                                               73.1
# 80                                                65.0
# 203                                                7.1
# 124                                               10.3
# 78                                                87.6
# 135                                               64.6
# 73                                                 -99
# 81                                                66.8
# 57                                                96.3
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 134                                                 41
# 185                                                143
# 80                                                  31
# 203                                                 80
# 124                                                 42
# 78                                                 116
# 135                                                 98
# 73                                                  73
# 81                                                 374
# 57                                                  47
#
#     Threatened species (number) Forested area (% of land area)  \
# 134                         8.1                       20.8/7.2
# 185                        62.0                       12.8/6.2
# 80                          0.0                       0.5/16.5
# 203                         3.8                        2.6/0.4
# 124                         3.9                        1.4/0.1
# 78                         32.7                      719.9/8.9
# 135                        61.5                        2.2/3.5
# 73                         98.9                        0.7/2.8
# 81                         31.2                       67.3/6.1
# 57                         14.4                       33.5/5.9
#
#     CO2 emission estimates (million tons/tons per capita)  \
# 134                                                677
# 185                                                154
# 80                                                 -99
# 203                                                111
# 124                                                 55
# 78                                                5004
# 135                                                 29
# 73                                                   3
# 81                                                 368
# 57                                                 666
#
#     Energy production, primary (Petajoules)  \
# 134                                      84
# 185                                     135
# 80                                      259
# 203                                      20
# 124                                       4
# 78                                      158
# 135                                      64
# 73                                       50
# 81                                       89
# 57                                      119
#
#     Energy supply per capita (Gigajoules)  \
# 134                             66.4/59.2
# 185                             99.7/99.4
# 80                                    -99
# 203                             91.4/44.2
# 124                             96.5/64.1
# 78                            100.0/100.0
# 135                            100.0/99.2
# 73                              94.5/75.1
# 81                            100.0/100.0
# 57                            100.0/100.0
#
#      Pop. using improved drinking water (urban/rural, %)  \
# 134                                          66.4/42.6
# 185                                          99.1/99.1
# 80                                                 -99
# 203                                           24.7/2.9
# 124                                          37.5/16.1
# 78                                           99.3/99.0
# 135                                          98.0/92.2
# 73                                           94.9/75.8
# 81                                           99.2/98.1
# 57                                           99.6/99.6
#
#      Pop. using improved sanitation facilities (urban/rural, %)  \
# 134                                               2.21
# 185                                                -99
# 80                                                 -99
# 203                                               5.51
# 124                                               9.45
# 78                                                 -99
# 135                                               2.44
# 73                                                 -99
# 81                                                 -99
# 57                                                 -99
#
#     Net Official Development Assist. received (% of GNI)
# 134                                                -99
# 185                                                -99
# 80                                                 -99
# 203                                                -99
# 124                                                -99
# 78                                                 -99
# 135                                                -99
# 73                                                 -99
# 81                                                 -99
# 57                                                 -99
#
# [10 rows x 50 columns]

# %%
# Produce the list of all df1 column names.
df.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'Population density (per km2, 2017)',
#        'Sex ratio (m per 100 f, 2017)',
#        'GDP: Gross domestic product (million current US$)',
#        'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP per capita (current US$)', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)',
#        'Unemployment (% of labour force)',
#        'Labour force participation (female/male pop. %)',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
#        'International trade: Balance (million US$)',
#        'Balance of payments, current account (million US$)',
#        'Population growth rate (average annual %)',
#        'Urban population (% of total population)',
#        'Urban population growth rate (average annual %)',
#        'Fertility rate, total (live births per woman)',
#        'Life expectancy at birth (females/males, years)',
#        'Population age distribution (0-14 / 60+ years, %)',
#        'International migrant stock (000/% of total pop.)',
#        'Refugees and others of concern to UNHCR (in thousands)',
#        'Infant mortality rate (per 1000 live births',
#        'Health: Total expenditure (% of GDP)',
#        'Health: Physicians (per 1000 pop.)',
#        'Education: Government expenditure (% of GDP)',
#        'Education: Primary gross enrol. ratio (f/m per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (f/m per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (f/m per 100 pop.)',
#        'Seats held by women in national parliaments %',
#        'Mobile-cellular subscriptions (per 100 inhabitants)',
#        'Mobile-cellular subscriptions (per 100 inhabitants).1',
#        'Individuals using the Internet (per 100 inhabitants)',
#        'Threatened species (number)', 'Forested area (% of land area)',
#        'CO2 emission estimates (million tons/tons per capita)',
#        'Energy production, primary (Petajoules)',
#        'Energy supply per capita (Gigajoules)',
#        'Pop. using improved drinking water (urban/rural, %)',
#        'Pop. using improved sanitation facilities (urban/rural, %)',
#        'Net Official Development Assist. received (% of GNI)'],
#       dtype='object')

# %%
#Use the loc function to provide major statistical indicators for columns from 'country' to 'Labour force participation (female/male pop. %)'.
df.loc[:,'country':'Labour force participation (female/male pop. %)']
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  \
# 0                           623.2                            23.3
# 1                          3984.2                            22.4
# 2                          4154.1                            12.2
# 3                           -99.0                             -99
# 4                         39896.4                             0.5
# ..                            ...                             ...
# 224                         -99.0                             -99
# 225                         -99.0                             -99
# 226                        1106.4                            14.7
# 227                        1311.1                             8.2
# 228                         890.4                            13.0
#
#      Economy: Industry (% of GVA)  \
# 0                            23.3
# 1                            26.0
# 2                            37.3
# 3                           -99.0
# 4                            10.8
# ..                            ...
# 224                         -99.0
# 225                         -99.0
# 226                          36.9
# 227                          32.3
# 228                          30.5
#
#      Economy: Services and other activity (% of GVA)  \
# 0                                               53.3
# 1                                               51.7
# 2                                               50.5
# 3                                              -99.0
# 4                                               88.6
# ..                                               ...
# 224                                            -99.0
# 225                                            -99.0
# 226                                             48.4
# 227                                             59.5
# 228                                             56.5
#
#     Employment: Agriculture (% of employed)  \
# 0                                      61.6
# 1                                      41.4
# 2                                      10.8
# 3                                       ...
# 4                                       -99
# ..                                      ...
# 224                                     -99
# 225                                    37.4
# 226                                    32.9
# 227                                    54.8
# 228                                    67.5
#
#     Employment: Industry (% of employed) Employment: Services (% of employed)  \
# 0                                   10.0                                 28.5
# 1                                   18.3                                 40.3
# 2                                   34.5                                 54.7
# 3                                    ...                                  ...
# 4                                    -99                                  -99
# ..                                   ...                                  ...
# 224                                  -99                                  -99
# 225                                 27.9                                 34.7
# 226                                 17.9                                 49.2
# 227                                  9.9                                 35.3
# 228                                  7.3                                 25.2
#
#     Unemployment (% of labour force)  \
# 0                                8.6
# 1                               15.8
# 2                               11.4
# 3                                ...
# 4                                -99
# ..                               ...
# 224                              -99
# 225                              6.8
# 226                             16.1
# 227                              7.4
# 228                              5.0
#
#     Labour force participation (female/male pop. %)
# 0                                         19.3/83.6
# 1                                         40.2/61.0
# 2                                         17.0/70.7
# 3                                           .../...
# 4                                               -99
# ..                                              ...
# 224                                             -99
# 225                                       28.6/83.3
# 226                                       26.2/73.7
# 227                                       69.9/80.9
# 228                                       78.0/87.5
#
# [229 rows x 17 columns]

# %%
#Create df2 consisting of 'country','Region','Surface area (km2)','Population in thousands (2017)','Population density (per km2, 2017)','Sex ratio (m per 100 f, 2017)','GDP: Gross domestic product (million current US$)','GDP per capita (current US$)','Unemployment (% of labour force)','Labour force participation (female/male pop. %)','Fertility rate, total (live births per woman)','Health: Total expenditure (% of GDP)','Individuals using the Internet (per 100 inhabitants)','CO2 emission estimates (million tons/tons per capita)' coming from df1.
df2=pd.read_csv('https://raw.githubusercontent.com/bartpiel/files-for-classes/refs/heads/main/Workshop-1/country_profile_variables.csv')

# %%
df2=df2.loc[0:229,'country':'CO2 emission estimates (million tons/tons per capita)']
df2
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                           91.1/131.6
# 1                                          111.7/115.5
# 2                                          112.7/119.5
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                         88.9/105.7
# 227                                        104.0/103.3
# 228                                         99.1/100.8
#
#      Education: Secondary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                            39.7/70.7
# 1                                            92.5/98.8
# 2                                           101.7/98.1
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                          39.5/57.4
# 227                                                -99
# 228                                          47.1/48.1
#
#     Education: Tertiary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                             3.7/13.3
# 1                                            68.1/48.7
# 2                                            45.1/28.9
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                           6.1/13.7
# 227                                            3.4/4.5
# 228                                            8.0/8.9
#
#     Seats held by women in national parliaments %  \
# 0                                            27.7
# 1                                            22.9
# 2                                            31.6
# 3                                           -99.0
# 4                                            32.1
# ..                                            ...
# 224                                         -99.0
# 225                                         -99.0
# 226                                           0.0
# 227                                          18.0
# 228                                          32.6
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 0                                                 61.6
# 1                                                106.4
# 2                                                113.0
# 3                                                  ...
# 4                                                 88.1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               68.0
# 227                                               74.5
# 228                                               84.8
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#      Threatened species (number)  Forested area (% of land area)  \
# 0                            2.1                         9.8/0.3
# 1                           28.2                         5.7/2.0
# 2                            0.8                       145.4/3.7
# 3                           87.9                             -99
# 4                           34.0                         0.5/6.4
# ..                           ...                             ...
# 224                         41.6                        ~0.0/1.6
# 225                          2.7                             -99
# 226                          1.0                        22.7/0.9
# 227                         65.6                         4.5/0.3
# 228                         37.2                        12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
# [229 rows x 45 columns]

# %%
df2
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                           91.1/131.6
# 1                                          111.7/115.5
# 2                                          112.7/119.5
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                         88.9/105.7
# 227                                        104.0/103.3
# 228                                         99.1/100.8
#
#      Education: Secondary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                            39.7/70.7
# 1                                            92.5/98.8
# 2                                           101.7/98.1
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                          39.5/57.4
# 227                                                -99
# 228                                          47.1/48.1
#
#     Education: Tertiary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                             3.7/13.3
# 1                                            68.1/48.7
# 2                                            45.1/28.9
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                           6.1/13.7
# 227                                            3.4/4.5
# 228                                            8.0/8.9
#
#     Seats held by women in national parliaments %  \
# 0                                            27.7
# 1                                            22.9
# 2                                            31.6
# 3                                           -99.0
# 4                                            32.1
# ..                                            ...
# 224                                         -99.0
# 225                                         -99.0
# 226                                           0.0
# 227                                          18.0
# 228                                          32.6
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 0                                                 61.6
# 1                                                106.4
# 2                                                113.0
# 3                                                  ...
# 4                                                 88.1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               68.0
# 227                                               74.5
# 228                                               84.8
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#      Threatened species (number)  Forested area (% of land area)  \
# 0                            2.1                         9.8/0.3
# 1                           28.2                         5.7/2.0
# 2                            0.8                       145.4/3.7
# 3                           87.9                             -99
# 4                           34.0                         0.5/6.4
# ..                           ...                             ...
# 224                         41.6                        ~0.0/1.6
# 225                          2.7                             -99
# 226                          1.0                        22.7/0.9
# 227                         65.6                         4.5/0.3
# 228                         37.2                        12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
# [229 rows x 45 columns]

# %%
# Rename columns in df2 as follows:
df2=df2.rename(columns={'country':'Country', 'Surface area (km2)':'Surface', 'Population in thousands (2017)' : 'Population', 'Population density (per km2, 2017)' : 'Population_density', 'Sex ratio (m per 100 f, 2017)' : 'Sex-ratio', 'GDP: Gross domestic product (million current US$)' : 'GDP', 'GDP per capita (current US$)' : 'GDP_per_capita', 'Unemployment (% of labour force)' : 'Unemployment', 'Labour force participation (female/male pop. %)' : 'Labour_force_participation', 'Individuals using the Internet (per 100 inhabitants)' : 'Internet_per_100', 'CO2 emission estimates (million tons/tons per capita)' : 'CO2_emission'
})

# %%
#Show the names of all columns in df2

df2.columns
# Out:
# Index(['Country', 'Region', 'Surface', 'Population', 'Population_density',
#        'Sex-ratio', 'GDP', 'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP_per_capita', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)', 'Unemployment',
#        'Labour_force_participation',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
#        'International trade: Balance (million US$)',
#        'Balance of payments, current account (million US$)',
#        'Population growth rate (average annual %)',
#        'Urban population (% of total population)',
#        'Urban population growth rate (average annual %)',
#        'Fertility rate, total (live births per woman)',
#        'Life expectancy at birth (females/males, years)',
#        'Population age distribution (0-14 / 60+ years, %)',
#        'International migrant stock (000/% of total pop.)',
#        'Refugees and others of concern to UNHCR (in thousands)',
#        'Infant mortality rate (per 1000 live births',
#        'Health: Total expenditure (% of GDP)',
#        'Health: Physicians (per 1000 pop.)',
#        'Education: Government expenditure (% of GDP)',
#        'Education: Primary gross enrol. ratio (f/m per 100 pop.)',
#        'Education: Secondary gross enrol. ratio (f/m per 100 pop.)',
#        'Education: Tertiary gross enrol. ratio (f/m per 100 pop.)',
#        'Seats held by women in national parliaments %',
#        'Mobile-cellular subscriptions (per 100 inhabitants)',
#        'Mobile-cellular subscriptions (per 100 inhabitants).1',
#        'Internet_per_100', 'Threatened species (number)',
#        'Forested area (% of land area)', 'CO2_emission'],
#       dtype='object')

# %%
# Show the last 10 rows in df2
df2.tail(10)
# Out:
#                                 Country             Region Surface  \
# 219                             Uruguay       SouthAmerica  173626
# 220                          Uzbekistan        CentralAsia  448969
# 221                             Vanuatu          Melanesia   12189
# 222  Venezuela (Bolivarian Republic of)       SouthAmerica  912050
# 223                            Viet Nam  South-easternAsia  330967
# 224           Wallis and Futuna Islands          Polynesia     142
# 225                      Western Sahara     NorthernAfrica  266000
# 226                               Yemen        WesternAsia  527968
# 227                              Zambia      EasternAfrica  752612
# 228                            Zimbabwe      EasternAfrica  390757
#
#      Population  Population_density  Sex-ratio     GDP  \
# 219        3457                19.8       93.5   53442
# 220       31911                75.0       99.4   69004
# 221         276                22.7      102.4     737
# 222       31977                36.3       99.0  344331
# 223       95541               308.1       98.0  193241
# 224          12                84.1       93.4     -99
# 225         553                 2.1      110.1     -99
# 226       28250                53.5      102.1   29688
# 227       17094                23.0       98.5   21255
# 228       16530                42.7       95.0   13893
#
#     GDP growth rate (annual %, const. 2005 prices)  GDP_per_capita  \
# 219                                            1.0         15573.8
# 220                                            6.8          2308.3
# 221                                           -1.0          2783.0
# 222                                           -6.2         11068.9
# 223                                            6.7          2067.9
# 224                                            -99           -99.0
# 225                                            -99           -99.0
# 226                                          -28.1          1106.4
# 227                                            2.9          1311.1
# 228                                            1.1           890.4
#
#     Economy: Agriculture (% of GVA)  ...  \
# 219                             6.8  ...
# 220                            19.2  ...
# 221                            26.7  ...
# 222                             5.3  ...
# 223                            18.9  ...
# 224                             -99  ...
# 225                             -99  ...
# 226                            14.7  ...
# 227                             8.2  ...
# 228                            13.0  ...
#
#      Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 219                                        107.3/109.8
# 220                                        103.2/105.6
# 221                                        118.7/120.6
# 222                                         98.6/101.3
# 223                                        108.4/109.3
# 224                                                -99
# 225                                                -99
# 226                                         88.9/105.7
# 227                                        104.0/103.3
# 228                                         99.1/100.8
#
#      Education: Secondary gross enrol. ratio (f/m per 100 pop.)  \
# 219                                         100.0/90.3
# 220                                          95.1/96.8
# 221                                          56.4/53.4
# 222                                          93.0/86.5
# 223                                                -99
# 224                                                -99
# 225                                                -99
# 226                                          39.5/57.4
# 227                                                -99
# 228                                          47.1/48.1
#
#     Education: Tertiary gross enrol. ratio (f/m per 100 pop.)  \
# 219                                            .../...
# 220                                           7.1/11.0
# 221                                            .../...
# 222                                            .../...
# 223                                          28.9/28.8
# 224                                                -99
# 225                                                -99
# 226                                           6.1/13.7
# 227                                            3.4/4.5
# 228                                            8.0/8.9
#
#     Seats held by women in national parliaments %  \
# 219                                          20.2
# 220                                          16.0
# 221                                           0.0
# 222                                          22.2
# 223                                          26.7
# 224                                         -99.0
# 225                                         -99.0
# 226                                           0.0
# 227                                          18.0
# 228                                          32.6
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 219                                              160.2
# 220                                               73.3
# 221                                               66.2
# 222                                               93.0
# 223                                              130.6
# 224                                                -99
# 225                                                -99
# 226                                               68.0
# 227                                               74.5
# 228                                               84.8
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1 Internet_per_100  \
# 219                                               64.6                 106
# 220                                               42.8                  59
# 221                                               22.4                 137
# 222                                               61.9                 328
# 223                                               52.7                 616
# 224                                                9.0                  89
# 225                                                -99                  49
# 226                                               25.1                 298
# 227                                               21.0                  88
# 228                                               16.4                  89
#
#      Threatened species (number)  Forested area (% of land area) CO2_emission
# 219                         10.4                         6.7/2.0          113
# 220                          7.6                       105.2/3.6         2339
# 221                         36.1                         0.2/0.6            1
# 222                         53.1                       185.2/6.1         7460
# 223                         47.2                       166.9/1.8         2977
# 224                         41.6                        ~0.0/1.6          -99
# 225                          2.7                             -99          -99
# 226                          1.0                        22.7/0.9          668
# 227                         65.6                         4.5/0.3          374
# 228                         37.2                        12.0/0.8          482
#
# [10 rows x 45 columns]

# %%
#. Create df2a consisting of rows 219 to 224 and columns from 'Country' to 'Sex-retio' from df2.
df2a=df2.loc[219:224, 'Country' : 'Sex-ratio']

df2a
# Out:
#                                 Country             Region Surface  \
# 219                             Uruguay       SouthAmerica  173626
# 220                          Uzbekistan        CentralAsia  448969
# 221                             Vanuatu          Melanesia   12189
# 222  Venezuela (Bolivarian Republic of)       SouthAmerica  912050
# 223                            Viet Nam  South-easternAsia  330967
# 224           Wallis and Futuna Islands          Polynesia     142
#
#      Population  Population_density  Sex-ratio
# 219        3457                19.8       93.5
# 220       31911                75.0       99.4
# 221         276                22.7      102.4
# 222       31977                36.3       99.0
# 223       95541               308.1       98.0
# 224          12                84.1       93.4

# %%
#Create df2b consisting of rows 223, 225, 227 and columns 'Country', 'Surface', 'Population_density'.
df2b=df2.loc[[223, 225, 227], ['Country', 'Surface', 'Population_density']]
df2b
# Out:
#             Country Surface  Population_density
# 223        Viet Nam  330967               308.1
# 225  Western Sahara  266000                 2.1
# 227          Zambia  752612                23.0

# %%
 # Show all indicators for Poland in df2
 df2[df2['Country'] == 'Poland']
# Out:
#     Country         Region Surface  Population  Population_density  Sex-ratio  \
# 160  Poland  EasternEurope  312679       38171               124.6       93.4
#
#         GDP GDP growth rate (annual %, const. 2005 prices)  GDP_per_capita  \
# 160  477066                                            3.9         12355.5
#
#     Economy: Agriculture (% of GVA)  ...  \
# 160                             2.6  ...
#
#      Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 160                                        100.7/100.5
#
#      Education: Secondary gross enrol. ratio (f/m per 100 pop.)  \
# 160                                        106.1/110.0
#
#     Education: Tertiary gross enrol. ratio (f/m per 100 pop.)  \
# 160                                          82.6/54.2
#
#     Seats held by women in national parliaments %  \
# 160                                          28.0
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 160                                              148.7
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1 Internet_per_100  \
# 160                                               68.0                  58
#
#      Threatened species (number)  Forested area (% of land area) CO2_emission
# 160                         30.7                       285.7/7.4         2819
#
# [1 rows x 45 columns]

# %%
# Show all unique values ​​for Region in df2.
df2['Region']
# Out:
# 0        SouthernAsia
# 1      SouthernEurope
# 2      NorthernAfrica
# 3           Polynesia
# 4      SouthernEurope
#             ...
# 224         Polynesia
# 225    NorthernAfrica
# 226       WesternAsia
# 227     EasternAfrica
# 228     EasternAfrica
# Name: Region, Length: 229, dtype: object

# %%
# Create df3 based on df2, which consists of the Eastern European region, with a Population of over 7000 and a Population density of over 60.
df3=df2[(df2['Region']=='EasternEurope') & (df2['Population']> 7000) & (df2['Population_density']>60)]
df3.head()
# Out:
#       Country         Region Surface  Population  Population_density  \
# 31   Bulgaria  EasternEurope  111002        7085                65.3
# 54    Czechia  EasternEurope   78868       10618               137.5
# 93    Hungary  EasternEurope   93024        9722               107.4
# 160    Poland  EasternEurope  312679       38171               124.6
# 166   Romania  EasternEurope  238391       19679                85.5
#
#      Sex-ratio     GDP GDP growth rate (annual %, const. 2005 prices)  \
# 31        94.6   48953                                            3.0
# 54        96.7  185156                                            4.5
# 93        90.7  121715                                            3.1
# 160       93.4  477066                                            3.9
# 166       94.0  177956                                            3.7
#
#      GDP_per_capita Economy: Agriculture (% of GVA)  ...  \
# 31           6846.8                             5.1  ...
# 54          17561.7                             2.5  ...
# 93          12350.6                             4.1  ...
# 160         12355.5                             2.6  ...
# 166          9120.7                             4.8  ...
#
#      Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 31                                           96.7/97.7
# 54                                           99.9/99.6
# 93                                         101.3/101.9
# 160                                        100.7/100.5
# 166                                          89.0/90.5
#
#      Education: Secondary gross enrol. ratio (f/m per 100 pop.)  \
# 31                                          97.4/100.5
# 54                                         106.1/105.1
# 93                                         105.3/105.1
# 160                                        106.1/110.0
# 166                                          92.0/92.5
#
#     Education: Tertiary gross enrol. ratio (f/m per 100 pop.)  \
# 31                                           82.9/65.4
# 54                                           76.3/54.2
# 93                                           56.7/45.3
# 160                                          82.6/54.2
# 166                                          59.0/47.8
#
#     Seats held by women in national parliaments %  \
# 31                                           19.2
# 54                                           20.0
# 93                                           10.1
# 160                                          28.0
# 166                                          20.7
#
#     Mobile-cellular subscriptions (per 100 inhabitants)  \
# 31                                               129.3
# 54                                               129.2
# 93                                               118.9
# 160                                              148.7
# 166                                              107.1
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1 Internet_per_100  \
# 31                                                56.7                 104
# 54                                                81.3                  53
# 93                                                72.8                  66
# 160                                               68.0                  58
# 166                                               55.8                 104
#
#      Threatened species (number)  Forested area (% of land area) CO2_emission
# 31                          35.1                        42.4/5.9          474
# 54                          34.5                        96.5/9.2         1221
# 93                          22.8                        42.1/4.3          423
# 160                         30.7                       285.7/7.4         2819
# 166                         29.5                        70.0/3.6         1109
#
# [5 rows x 45 columns]

# %%
#.Create histograms for Population and GDP per capita from df2.
df2.hist(column=['Population','GDP'])
# Out:
# array([[<Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'GDP'}>]], dtype=object)

# %%
#  Save df3 as EasternEurope.json with separated records.
df3[df3['Region']=='EasternEurope'][['Population', 'Population_density']].to_json('EasternEurope.json',orient='records')
